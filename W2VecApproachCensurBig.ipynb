# %%
import pandas as pd
import numpy as np

#col_names=['age','work_place','fnlwgt','education','education_num','marital_status','occupation',
#           'relationship','race','gender','capital_gain','captial_loss','hours_per_week','native_country','target']


data_path = "./census/"

income_data = pd.read_csv(data_path+'census-income.data', sep=',', header=None)


#pf.columns = col_names
#change column names
new_col_names =['age', 'class_of_worker', 'industry_code', 'occupation_code', 'education', 'wage_per_hour', 'enrolled_in_edu_inst_last_week', 'marital_status', 'major_industry_code', 'major_occupation_code', 'race', 'hispanic_origin', 'sex', 'member_of_labor_union', 'reason_for_unemployment', 'employment_status', 'capital_gains', 'capital_losses', 'dividends', 'tax_filer_status', 'previous_residence_region', 'previous_residence_state', 'detailed_household_summary_stat','detailed_household_summary_household',  'what2', 'migration_msa_change', 'migration_reg_change', 'migration_within_reg_change', 'live_in_this_house_1yr_ago', 'previous_residence_sunbelt', 'num_persons_worked_for_employer', 'family_members_under_18', 'birthplace_father', 'birthplace_mother', 'birthplace_self', 'citizenship', 'self_employed', 'veteran_questionnaire_filler', 'veterans_benefits', 'weeks_worked_in_year', 'year', 'target']
#print(new_col_names)
income_data.columns = new_col_names

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(income_data,income_data.target,test_size=0.2, random_state=1500)

# %%
def income_data_prep(income_data):
    '''
    input: data frame. here the data propressing is customized for bank data
    '''
    income_data.dropna(inplace=True)  
    
    #remove useless columns
    re_corr_cols= ['industry_code', 'occupation_code', 'education', 'wage_per_hour',"detailed_household_summary_stat","what2"]
    income_data.drop(re_corr_cols,axis=1,inplace=True)
    
    # we found out that clients from year 1995, the entire re_miss_cols has missing values
    re_miss_cols = ['migration_msa_change','migration_reg_change', 'migration_within_reg_change','previous_residence_sunbelt']
    income_data.drop(re_miss_cols,axis=1,inplace=True)   
    
    # Remove leading and trailing whitespace from all values in the dataframe
    income_data = income_data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # change ['hispanic_origin'] NA to "Do not know"
    income_data['hispanic_origin'] = income_data['hispanic_origin'].replace("NA", "Do not know")
    
    #change the number to string for object features

    # define a dictionary to map numerical values to string values
    employ_map = {0: 'employee', 1: 'selfemployed',2: 'ownbusiness'}
    # use the replace method to map numerical values to string values
    income_data["self_employed"] = income_data["self_employed"].replace(employ_map)
    
    veterans_map = {0: 'A',1: 'B', 2: 'C'}
    # use the replace method to map numerical values to string values
    income_data['veterans_benefits'] = income_data['veterans_benefits'].replace(veterans_map)

    
    year_map = {94: '1994', 95: '1995'}
    # use the replace method to map numerical values to string values
    income_data['year'] = income_data['year'].replace(year_map)
    
    # get the list of columns that contain '?'    
    cols_with_question_mark =income_data.applymap(lambda x: isinstance(x, str) and '?' in x).any()
    columns_to_replace = cols_with_question_mark[cols_with_question_mark == True].index.tolist()
    #print(columns_to_replace)
    for column in columns_to_replace:
         income_data[column] = income_data[column].replace('?', np.nan)
    
    # replace "?" with NA
   # income_data.replace({'?', np.NaN}, inplace=True)
    #remove NAs
    income_data.dropna(inplace=True)
    
    # change the target values 
    income_data["target"]=  np.where(income_data["target"] =="50000+.",1,0)

    # Get all categorical features
    cat_columns = list(income_data.columns[income_data.dtypes=='object'])   
    # cat_columns.remove('target')
    
    #remove NA string
    #income_data.replace('NA', np.nan, inplace=True)
    #income_data.dropna(inplace=True)

    return(income_data,cat_columns)

# %%
#data pre-processing 
#data pre-processing 
df_income, cat_cols=income_data_prep(X_train)
df_income_test, cat_cols = income_data_prep(X_test)


y_train = df_income.target
y_test = df_income_test.target

# %%
len(y_train)
len(y_test)
# Out:
# 38057

# %%
df_income.head().agg(lambda x: print(x["class_of_worker"]), axis=1)
# Out:
# Private
# Not in universe
# Private
# Not in universe
# Not in universe
# 170868    None
# 110370    None
# 139696    None
# 11112     None
# 106644    None
# dtype: object

# %%
df_income[cat_cols] = df_income[cat_cols].applymap(lambda x: x.replace(" ","-"))
df_income_test[cat_cols] = df_income_test[cat_cols].applymap(lambda x: x.replace(" ","-"))

# %%
df_income["year"]
# Out:
# 170868    1994
# 110370    1994
# 139696    1995
# 11112     1994
# 106644    1995
#           ...
# 193390    1994
# 181117    1994
# 155841    1995
# 120651    1995
# 77075     1995
# Name: year, Length: 152504, dtype: object

# %%
categorical_cols = list(df_income.dtypes[df_income.dtypes=="object"].keys())

# %%
categorical_cols
# Out:
# ['class_of_worker',
#  'enrolled_in_edu_inst_last_week',
#  'marital_status',
#  'major_industry_code',
#  'major_occupation_code',
#  'race',
#  'hispanic_origin',
#  'sex',
#  'member_of_labor_union',
#  'reason_for_unemployment',
#  'employment_status',
#  'tax_filer_status',
#  'previous_residence_region',
#  'previous_residence_state',
#  'detailed_household_summary_household',
#  'live_in_this_house_1yr_ago',
#  'family_members_under_18',
#  'birthplace_father',
#  'birthplace_mother',
#  'birthplace_self',
#  'citizenship',
#  'self_employed',
#  'veteran_questionnaire_filler',
#  'veterans_benefits',
#  'year']

# %%
df_income['stringcat'] = df_income.agg(lambda x: f"{x['class_of_worker']} {x['enrolled_in_edu_inst_last_week']}  {x['marital_status']}  {x['major_industry_code']}  {x['major_occupation_code']}  {x['race']} {x['hispanic_origin']} {x['sex']}  {x['member_of_labor_union']}  {x['reason_for_unemployment']} {x['employment_status']}  {x['tax_filer_status']}  {x['previous_residence_region']}  {x['previous_residence_state']} {x['detailed_household_summary_household']}  {x['live_in_this_house_1yr_ago']}  {x['family_members_under_18']} {x['birthplace_father']}  {x['birthplace_mother']}  {x['birthplace_mother']}  {x['birthplace_self']}   {x['citizenship']}  {x['self_employed']}  {x['veteran_questionnaire_filler']}  {x['veterans_benefits']}  {x['year']} ", axis=1)

# %%
from gensim.test.utils import common_texts

from gensim.models import Word2Vec

# %%
dimpool = 30
model = Word2Vec(sentences=df_income['stringcat'].str.split(" "), vector_size=dimpool, window=2, min_count=1, workers=4)

model.save("word2vec.model.income")

# %%
df_income['stringcat']
# Out:
# 170868    Private Not-in-universe  Never-married  Financ...
# 110370    Not-in-universe Not-in-universe  Divorced  Not...
# 139696    Private Not-in-universe  Married-civilian-spou...
# 11112     Not-in-universe Not-in-universe  Married-civil...
# 106644    Not-in-universe Not-in-universe  Never-married...
#                                 ...
# 193390    Not-in-universe Not-in-universe  Never-married...
# 181117    Not-in-universe Not-in-universe  Married-civil...
# 155841    Not-in-universe Not-in-universe  Never-married...
# 120651    Private Not-in-universe  Never-married  Constr...
# 77075     Not-in-universe Not-in-universe  Married-civil...
# Name: stringcat, Length: 152504, dtype: object

# %%
df_income['stringcat'].str.split(" ")
# Out:
# 170868    [Private, Not-in-universe, , Never-married, , ...
# 110370    [Not-in-universe, Not-in-universe, , Divorced,...
# 139696    [Private, Not-in-universe, , Married-civilian-...
# 11112     [Not-in-universe, Not-in-universe, , Married-c...
# 106644    [Not-in-universe, Not-in-universe, , Never-mar...
#                                 ...
# 193390    [Not-in-universe, Not-in-universe, , Never-mar...
# 181117    [Not-in-universe, Not-in-universe, , Married-c...
# 155841    [Not-in-universe, Not-in-universe, , Never-mar...
# 120651    [Private, Not-in-universe, , Never-married, , ...
# 77075     [Not-in-universe, Not-in-universe, , Married-c...
# Name: stringcat, Length: 152504, dtype: object

# %%
columns_categorical = cat_cols

# %%
from tqdm import tqdm_notebook as tqdm

elements = []


for row in tqdm(df_income.iterrows()):
    categorical_embeddings = []
    for i in columns_categorical:
        #print(i,row[1][i])
        try:
            
            categorical_embeddings.append(model.wv[row[1][i]])
        except:
            categorical_embeddings.append(np.zeros((dimpool)))
    elements.append(np.array(categorical_embeddings))
# Out:
# /tmp/ipykernel_133680/2699079202.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for row in tqdm(df_income.iterrows()):
# 0it [00:00, ?it/s]

# %%
elements[0]
# Out:
# array([[ 9.71528649e-01,  2.53408879e-01, -4.95787716e+00,
#          4.39093113e+00,  5.90402508e+00,  1.73303521e+00,
#         -6.23992383e-01, -2.44400716e+00, -1.04024816e+00,
#          4.63740921e+00,  1.69965780e+00, -2.97356343e+00,
#          1.45111978e+00, -1.36095986e-01,  4.81407070e+00,
#          7.47750378e+00,  1.13175106e+00,  1.78077114e+00,
#         -5.80858588e-01, -1.99191794e-01,  6.55080700e+00,
#          4.93402338e+00,  1.92034924e+00, -6.62984276e+00,
#         -4.22747707e+00, -6.42770454e-02, -2.75742888e-01,
#         -4.07873631e+00,  2.46035051e+00,  4.46570921e+00],
#        [ 7.18490183e-01, -8.33356082e-01,  1.03425428e-01,
#         -2.08595857e-01,  4.41765487e-01,  2.10303235e+00,
#         -3.18044871e-01, -2.01902300e-01,  3.41060698e-01,
#          8.01150084e-01, -1.13940060e+00,  2.54227638e-01,
#         -1.73210418e+00,  1.83080387e+00, -1.74183404e+00,
#          1.60659492e+00,  1.06867516e+00, -9.48434651e-01,
#          6.64179742e-01, -1.52156532e-01, -1.33667541e+00,
#         -1.26712000e+00, -1.43721294e+00, -4.40834939e-01,
#          2.20667577e+00, -1.58871174e+00, -4.24336523e-01,
#          2.22375059e+00, -5.25368989e-01,  1.37176597e+00],
#        [ 5.56813061e-01, -2.67532563e+00, -3.08110738e+00,
#          2.86568999e-01, -3.02825904e+00,  3.44968349e-01,
#         -2.75109386e+00, -2.38372040e+00,  2.48042417e+00,
#          3.17439032e+00,  9.59154144e-02, -4.62120867e+00,
#          7.41978586e-01,  2.98877883e+00,  2.46037745e+00,
#         -2.58705544e+00,  1.62498903e+00, -5.52687168e-01,
#         -1.43018758e+00, -1.28431213e+00, -2.39945069e-01,
#          2.69439650e+00, -1.20975101e+00, -1.05820525e+00,
#          9.91026342e-01, -9.89279449e-01, -3.22755724e-01,
#          4.31557703e+00, -2.60424137e+00,  3.74965835e+00],
#        [ 2.66042614e+00,  2.23916292e+00, -2.01832676e+00,
#          4.45427847e+00, -2.25494528e+00,  2.56101847e-01,
#          2.71399522e+00,  9.67945814e-01, -4.88266563e+00,
#          8.01150084e-01, -1.13940060e+00,  2.54227638e-01,
#         -1.73210418e+00,  1.83080387e+00, -1.74183404e+00,
#          1.60659492e+00,  1.06867516e+00, -9.48434651e-01,
#          6.64179742e-01, -1.52156532e-01, -1.33667541e+00,
#         -1.26712000e+00, -1.43721294e+00, -4.40834939e-01,
#          2.20667577e+00, -1.58871174e+00, -4.24336523e-01,
#          2.22375059e+00, -5.25368989e-01,  1.37176597e+00],
#        [-6.90359533e-01,  5.42277479e+00,  1.21371225e-01,
#          1.33814943e+00, -3.39802718e+00, -1.58011723e+00,
#          1.26268756e+00,  3.20424390e+00,  1.88939369e+00,
#         -6.44801021e-01, -1.45747244e+00, -1.07019258e+00,
#          3.88030231e-01, -9.70090389e-01,  3.14337206e+00,
#         -1.23215402e-02,  2.10060358e+00,  2.51165843e+00,
#         -6.53661132e-01,  7.62363195e-01,  4.72797823e+00,
#          2.03526258e+00,  7.62515903e-01,  1.01128042e+00,
#          4.60538477e-01,  1.83406043e+00,  4.64391857e-01,
#         -2.97647548e+00, -4.13332492e-01, -2.76772141e+00],
#        [ 5.92058063e-01,  5.55497742e+00,  6.81417882e-01,
#          1.59930968e+00, -3.31931639e+00, -1.32769215e+00,
#          4.54393238e-01,  2.85021901e+00,  2.94257760e+00,
#          2.35909557e+00, -1.47657812e+00,  2.14318767e-01,
#          3.44129872e+00, -6.54470563e-01,  3.43286061e+00,
#         -9.34869766e-01,  1.27894700e-01,  6.16710246e-01,
#         -1.81368232e+00, -1.57135069e+00,  4.16594744e+00,
#         -1.90410936e+00,  3.04135346e+00,  3.01973152e+00,
#         -1.62912726e+00,  3.06556630e+00,  4.73898023e-01,
#         -3.74124670e+00, -1.62171042e+00, -5.59038103e-01]], dtype=float32)

# %%
elements

reshaped_x = (np.reshape(elements,(152504,len(columns_categorical)*dimpool)))

# %%
df_income.dtypes
# Out:
# age                                      int64
# class_of_worker                         object
# enrolled_in_edu_inst_last_week          object
# marital_status                          object
# major_industry_code                     object
# major_occupation_code                   object
# race                                    object
# hispanic_origin                         object
# sex                                     object
# member_of_labor_union                   object
# reason_for_unemployment                 object
# employment_status                       object
# capital_gains                            int64
# capital_losses                           int64
# dividends                                int64
# tax_filer_status                        object
# previous_residence_region               object
# previous_residence_state                object
# detailed_household_summary_household    object
# live_in_this_house_1yr_ago              object
# num_persons_worked_for_employer          int64
# family_members_under_18                 object
# birthplace_father                       object
# birthplace_mother                       object
# birthplace_self                         object
# citizenship                             object
# self_employed                           object
# veteran_questionnaire_filler            object
# veterans_benefits                       object
# weeks_worked_in_year                     int64
# year                                    object
# target                                   int64
# stringcat                               object
# dtype: object

# %%
del df_income['stringcat']
del df_income['target']

# %%
df_income
# Out:
#         age  class_of_worker enrolled_in_edu_inst_last_week
# 170868   25          Private                Not-in-universe  \
# 110370   37  Not-in-universe                Not-in-universe
# 139696   33          Private                Not-in-universe
# 11112     2  Not-in-universe                Not-in-universe
# 106644   48  Not-in-universe                Not-in-universe
# ...     ...              ...                            ...
# 193390    9  Not-in-universe                Not-in-universe
# 181117   85  Not-in-universe                Not-in-universe
# 155841    3  Not-in-universe                Not-in-universe
# 120651   30          Private                Not-in-universe
# 77075    51  Not-in-universe                Not-in-universe
#
#                          marital_status                major_industry_code
# 170868                    Never-married  Finance-insurance-and-real-estate  \
# 110370                         Divorced        Not-in-universe-or-children
# 139696  Married-civilian-spouse-present  Finance-insurance-and-real-estate
# 11112   Married-civilian-spouse-present        Not-in-universe-or-children
# 106644                    Never-married        Not-in-universe-or-children
# ...                                 ...                                ...
# 193390                    Never-married        Not-in-universe-or-children
# 181117  Married-civilian-spouse-present        Not-in-universe-or-children
# 155841                    Never-married        Not-in-universe-or-children
# 120651                    Never-married                       Construction
# 77075   Married-civilian-spouse-present        Not-in-universe-or-children
#
#                       major_occupation_code                       race
# 170868       Adm-support-including-clerical                      Black  \
# 110370                      Not-in-universe                      White
# 139696       Executive-admin-and-managerial                      White
# 11112                       Not-in-universe  Asian-or-Pacific-Islander
# 106644                      Not-in-universe                      White
# ...                                     ...                        ...
# 193390                      Not-in-universe                      Black
# 181117                      Not-in-universe                      White
# 155841                      Not-in-universe                      White
# 120651  Precision-production-craft-&-repair                      White
# 77075                       Not-in-universe                      White
#
#          hispanic_origin     sex member_of_labor_union  ...
# 170868         All-other    Male       Not-in-universe  ...  \
# 110370         All-other  Female       Not-in-universe  ...
# 139696         All-other  Female                    No  ...
# 11112       Puerto-Rican    Male       Not-in-universe  ...
# 106644      Puerto-Rican  Female       Not-in-universe  ...
# ...                  ...     ...                   ...  ...
# 193390         All-other  Female       Not-in-universe  ...
# 181117         All-other    Male       Not-in-universe  ...
# 155841         All-other    Male       Not-in-universe  ...
# 120651         All-other    Male                    No  ...
# 77075   Mexican-American  Female       Not-in-universe  ...
#
#        family_members_under_18 birthplace_father  birthplace_mother
# 170868         Not-in-universe     United-States      United-States  \
# 110370         Not-in-universe            Canada      United-States
# 139696         Not-in-universe     United-States      United-States
# 11112          Not-in-universe       Puerto-Rico        Puerto-Rico
# 106644         Not-in-universe       Puerto-Rico        Puerto-Rico
# ...                        ...               ...                ...
# 193390     Mother-only-present     United-States      United-States
# 181117         Not-in-universe     United-States      United-States
# 155841    Both-parents-present     United-States      United-States
# 120651         Not-in-universe     United-States      United-States
# 77075          Not-in-universe            Mexico             Mexico
#
#         birthplace_self                                  citizenship
# 170868    United-States            Native--Born-in-the-United-States  \
# 110370    United-States            Native--Born-in-the-United-States
# 139696    United-States            Native--Born-in-the-United-States
# 11112       Puerto-Rico  Native--Born-in-Puerto-Rico-or-U-S-Outlying
# 106644      Puerto-Rico  Native--Born-in-Puerto-Rico-or-U-S-Outlying
# ...                 ...                                          ...
# 193390    United-States            Native--Born-in-the-United-States
# 181117    United-States            Native--Born-in-the-United-States
# 155841    United-States            Native--Born-in-the-United-States
# 120651    United-States            Native--Born-in-the-United-States
# 77075            Mexico           Foreign-born--Not-a-citizen-of-U-S
#
#        self_employed veteran_questionnaire_filler veterans_benefits
# 170868   ownbusiness              Not-in-universe                 C  \
# 110370      employee              Not-in-universe                 C
# 139696      employee              Not-in-universe                 C
# 11112       employee              Not-in-universe                 C
# 106644      employee              Not-in-universe                 C
# ...              ...                          ...               ...
# 193390      employee              Not-in-universe                 A
# 181117      employee              Not-in-universe                 C
# 155841      employee              Not-in-universe                 A
# 120651      employee              Not-in-universe                 C
# 77075       employee              Not-in-universe                 C
#
#        weeks_worked_in_year  year
# 170868                   52  1994
# 110370                    0  1994
# 139696                   52  1995
# 11112                     0  1994
# 106644                   12  1995
# ...                     ...   ...
# 193390                    0  1994
# 181117                    0  1994
# 155841                    0  1995
# 120651                   52  1995
# 77075                     0  1995
#
# [152504 rows x 31 columns]

# %%
np.where(df_income.dtypes!="object")[0]
# Out:
# array([ 0, 12, 13, 14, 20, 29])

# %%
df_income_num = df_income.iloc[:, [ 0, 12, 13, 14, 20, 29]].reset_index()
del df_income_num["index"]

# %%
df_income_num.head()
# Out:
#    age  capital_gains  capital_losses  dividends
# 0   25              0               0          0  \
# 1   37              0               0          0
# 2   33              0               0        250
# 3    2              0               0          0
# 4   48              0               0          0
#
#    num_persons_worked_for_employer  weeks_worked_in_year
# 0                                6                    52
# 1                                0                     0
# 2                                6                    52
# 3                                0                     0
# 4                                1                    12

# %%
my_data = pd.concat([df_income_num,pd.DataFrame(reshaped_x)],axis=1)

my_data.head()
# Out:
#    age  capital_gains  capital_losses  dividends
# 0   25              0               0          0  \
# 1   37              0               0          0
# 2   33              0               0        250
# 3    2              0               0          0
# 4   48              0               0          0
#
#    num_persons_worked_for_employer  weeks_worked_in_year         0         1
# 0                                6                    52  0.971529  0.253409  \
# 1                                0                     0  0.718490 -0.833356
# 2                                6                    52  0.971529  0.253409
# 3                                0                     0  0.718490 -0.833356
# 4                                1                    12  0.718490 -0.833356
#
#           2         3  ...       740       741       742       743       744
# 0 -4.957877  4.390931  ...  4.165947 -1.904109  3.041353  3.019732 -1.629127  \
# 1  0.103425 -0.208596  ...  4.165947 -1.904109  3.041353  3.019732 -1.629127
# 2 -4.957877  4.390931  ...  4.557215  0.002884  2.638560  0.596689 -1.718802
# 3  0.103425 -0.208596  ...  4.165947 -1.904109  3.041353  3.019732 -1.629127
# 4  0.103425 -0.208596  ...  4.557215  0.002884  2.638560  0.596689 -1.718802
#
#         745       746       747       748       749
# 0  3.065566  0.473898 -3.741247 -1.621710 -0.559038
# 1  3.065566  0.473898 -3.741247 -1.621710 -0.559038
# 2  2.135884  0.993245 -4.360782 -1.234738 -4.189466
# 3  3.065566  0.473898 -3.741247 -1.621710 -0.559038
# 4  2.135884  0.993245 -4.360782 -1.234738 -4.189466
#
# [5 rows x 756 columns]

# %%
my_data["target"] = y_train.values

# %%
my_data.to_csv('census_w2vec_paired_ttest.csv')

# %%
from sklearn.model_selection import train_test_split


X_train2, X_test2, y_train2, y_test2 = train_test_split(my_data,y_train,test_size=0.2, random_state=1500)

# %%
X_train2.head()
# Out:
#        age  capital_gains  capital_losses  dividends
# 97034   46              0               0          0  \
# 39782   60              0               0          0
# 52743   11              0               0          0
# 62458   25              0               0          0
# 15742   40              0               0          0
#
#        num_persons_worked_for_employer  weeks_worked_in_year         0
# 97034                                1                    52 -2.620790  \
# 39782                                6                    52 -4.346836
# 52743                                0                     0  0.949587
# 62458                                6                    52 -4.346836
# 15742                                4                    52 -4.346836
#
#               1         2         3  ...       740       741       742
# 97034 -0.719483 -1.934697 -0.245091  ... -0.577736 -1.884557  2.849357  \
# 39782 -0.429085 -4.042089 -1.993753  ...  0.021078 -2.286480  1.125948
# 52743 -2.220054  0.689826  0.021175  ... -0.577736 -1.884557  2.849357
# 62458 -0.429085 -4.042089 -1.993753  ...  0.021078 -2.286480  1.125948
# 15742 -0.429085 -4.042089 -1.993753  ...  0.021078 -2.286480  1.125948
#
#             743       744       745       746       747       748       749
# 97034  4.034204 -1.547950  0.945969  3.525007  2.184367 -1.472942 -1.589378
# 39782  1.499001 -0.352019 -0.392285  2.319086  1.507847 -0.871454 -3.148458
# 52743  4.034204 -1.547950  0.945969  3.525007  2.184367 -1.472942 -1.589378
# 62458  1.499001 -0.352019 -0.392285  2.319086  1.507847 -0.871454 -3.148458
# 15742  1.499001 -0.352019 -0.392285  2.319086  1.507847 -0.871454 -3.148458
#
# [5 rows x 756 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,classification_report,auc, roc_auc_score


log = LogisticRegression(max_iter=1000)


stc = StandardScaler()

X_scaled = stc.fit_transform(X_train2.values)

log.fit(X_scaled,y_train2)

y_pred = log.predict(stc.transform(X_test2.values))
y_pred_prob = log.predict_proba(stc.transform(X_test2.values))

print(confusion_matrix(y_test2,y_pred))
print(classification_report(y_test2,y_pred))

print(roc_auc_score(y_test2,y_pred_prob[:,1]))
# Out:
# /home/sbr@pwo.ou.nl/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[28367   229]
#  [ 1300   605]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     28596
#            1       0.73      0.32      0.44      1905
#
#     accuracy                           0.95     30501
#    macro avg       0.84      0.65      0.71     30501
# weighted avg       0.94      0.95      0.94     30501
#
# 0.939424506997473

# %%
df_bank_test.head()
# Out:
#        age          job  marital            education default  housing
# 34578   32  blue-collar   single          high.school      no      yes  \
# 36326   21   management   single    university.degree      no  unknown
# 5595    41      unknown   single             basic.9y      no       no
# 1323    49   technician  married  professional.course      no       no
# 4141    33  blue-collar  married             basic.9y      no  unknown
#
#           loan    contact month day_of_week  duration  campaign  pdays
# 34578       no   cellular   may         thu       216         1    999  \
# 36326  unknown   cellular   jun         tue       106         1    999
# 5595       yes  telephone   may         mon       369         1    999
# 1323        no  telephone   may         thu        63         2    999
# 4141   unknown  telephone   may         mon       215         3    999
#
#        previous     poutcome  y
# 34578         0  nonexistent  0
# 36326         0  nonexistent  0
# 5595          0  nonexistent  0
# 1323          0  nonexistent  0
# 4141          0  nonexistent  0

# %%
from tqdm import tqdm_notebook as tqdm

elements = []


for row in tqdm(df_income_test.iterrows()):
    categorical_embeddings = []
    for i in columns_categorical:
        #print(i,row[1][i])
        try:
            categorical_embeddings.append(model.wv[row[1][i]])
        except:
            categorical_embeddings.append(np.zeros((dimpool)))
    elements.append(np.array(categorical_embeddings))
# Out:
# /tmp/ipykernel_133680/359935766.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   
# 4  0.162616  0.139855 -0.110055  1.181512  0.770473  0.781663  0.877373
#
#         268       269       270       271       272       273       274
# 0  0.151010  0.348313 -0.408219  1.140387 -0.537646  0.667966  0.865984  \
# 1  0.202703  0.461435 -0.408219  1.140387 -0.537646  0.667966  0.865984
# 2  0.193223  0.410664 -0.408219  1.140387 -0.537646  0.667966  0.865984
# 3  0.151010  0.348313 -0.408219  1.140387 -0.537646  0.667966  0.865984
# 4  0.193223  0.410664 -0.408219  1.140387 -0.537646  0.667966  0.865984
#
#        275       276       277       278       279       280       281
# 0  0.38015  0.590908 -1.093774  0.248988  0.167887 -0.110277  0.663152  \
# 1  0.38015  0.590908 -1.093774  0.248988  0.167887 -0.110277  0.663152
# 2  0.38015  0.590908 -1.093774  0.248988  0.167887 -0.110277  0.663152
# 3  0.38015  0.590908 -1.093774  0.248988  0.167887 -0.110277  0.663152
# 4  0.38015  0.590908 -1.093774  0.248988  0.167887 -0.110277  0.663152
#
#         282       283       284       285       286       287       288
# 0 -0.492732 -0.466525 -0.044248  0.646224 -1.035201  0.378048 -0.079573  \
# 1 -0.492732 -0.466525 -0.044248  0.646224 -1.035201  0.378048 -0.079573
# 2 -0.492732 -0.466525 -0.044248  0.646224 -1.035201  0.378048 -0.079573
# 3 -0.492732 -0.466525 -0.044248  0.646224 -1.035201  0.378048 -0.079573
# 4 -0.492732 -0.466525 -0.044248  0.646224 -1.035201  0.378048 -0.079573
#
#         289      290       291       292       293       294       295
# 0 -1.190863  0.14809  0.978977 -0.660713  0.096484  0.045345 -0.202588  \
# 1 -1.190863  0.14809  0.978977 -0.660713  0.096484  0.045345 -0.202588
# 2 -1.190863  0.14809  0.978977 -0.660713  0.096484  0.045345 -0.202588
# 3 -1.190863  0.14809  0.978977 -0.660713  0.096484  0.045345 -0.202588
# 4 -1.190863  0.14809  0.978977 -0.660713  0.096484  0.045345 -0.202588
#
#         296       297       298       299
# 0 -0.534431 -0.484841 -0.785899  1.558576
# 1 -0.534431 -0.484841 -0.785899  1.558576
# 2 -0.534431 -0.484841 -0.785899  1.558576
# 3 -0.534431 -0.484841 -0.785899  1.558576
# 4 -0.534431 -0.484841 -0.785899  1.558576

# %%
reshaped_x_test = (np.reshape(elements,(38057,len(columns_categorical)*dimpool)))

df_income_test2 = df_income_test.iloc[:, [ 0, 12, 13, 14, 20, 29]].reset_index()

del df_income_test2["index"]
#del df_bank_test['target']

my_test_data = pd.concat([df_income_test2,pd.DataFrame(reshaped_x_test)],axis=1)
my_test_data


from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,auc, roc_auc_score



y_pred_test = log.predict(stc.transform(my_test_data.values))
y_pred_prob_test = log.predict_proba(stc.transform(my_test_data.values))

print(confusion_matrix(y_test,y_pred_test))
print(classification_report(y_test,y_pred_test))

print(roc_auc_score(y_test,y_pred_prob_test[:,1]))
# Out:
# [[35419   324]
#  [ 1632   682]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     35743
#            1       0.68      0.29      0.41      2314
#
#     accuracy                           0.95     38057
#    macro avg       0.82      0.64      0.69     38057
# weighted avg       0.94      0.95      0.94     38057
#
# 0.9340151365320433
